# %%
## Exercise 1

To manage a server, administrators want to estimate the average number of simultaneous users.

At 100 randomly selected moments, the average number of users was 37.7.
The population standard deviation is known to be σ = 9.2 users.

a) Compute a 90% confidence interval for the true mean number of users.

b) Based on the confidence interval, can we conclude that the true average number of users
is greater than 35?

# %%
## Exercise 2

Installation time for a certain software follows a normal distribution.
The population standard deviation is σ = 5 minutes.

A technician installs the software on 64 computers and obtains a sample mean of 42 minutes.

a) Compute a 95% confidence interval for the true mean installation time.

b) If the true mean installation time is 40 minutes,
what is the probability that a randomly selected installation time
lies within the confidence interval computed in part (a)?

# %% [markdown]
# ## Exercise 3
#
# The salaries of entry-level computer engineers follow a **Normal distribution** with an unknown mean and variance. Three randomly selected computer engineers have the following salaries (in $1000s):
#
# - 30, 50, 70
#
# #### (a) Construct a 90% confidence interval for the average salary of an entry-level computer engineer.
#
# Using the given salaries, construct a 90% confidence interval for the average salary of an entry-level computer engineer.
#
# #### (b) Does this sample provide significant evidence, at a 10% level of significance, that the average salary of all entry-level computer engineers is different from $80,000? Explain.
#
# At a significance level of 10%, test whether the average salary of all entry-level computer engineers is different from $80,000. Provide an explanation.
#
# #### (c) Looking at this sample, one may think that the starting salaries have a great deal of variability. Construct a 90% confidence interval for the standard deviation of entry-level salaries.
#
# Using the sample of salaries, construct a 90% confidence interval for the standard deviation of entry-level computer engineers’ salaries.

# %%
## Exercise 4

Let X₁, …, Xₙ be an i.i.d. sample from an Exponential distribution with parameter λ > 0,
with probability density function

f(x; λ) = λ e^{-λx},   x ≥ 0.

**(a)** Find the likelihood function and derive the Maximum Likelihood Estimator (MLE) of λ.

**(b)** Compute the Fisher information per observation I(λ) and for the full sample Iₙ(λ).
Write down the Cramér–Rao Lower Bound (CRLB) for any unbiased estimator of λ.

**(c)** Determine whether the MLE achieves the CRLB (i.e. whether it is efficient).
Comment on whether this holds exactly or only asymptotically.

**(d)** Using Fisher information and the asymptotic normality of the MLE, construct a
Wald-type confidence interval for λ with confidence level 95%.

**(e)** Define θ = 1 / λ (the mean of the exponential distribution).
Use the **delta method** to obtain the asymptotic variance of θ̂ = 1 / λ̂ and construct
an approximate 95% confidence interval for θ.

**(f)** Numerical illustration:
Simulate a sample of size n = 30 from Exp(λ = 0.2) and compute:

1. The MLE of λ
2. The theoretical and observed Fisher information
3. The CRLB
4. The confidence interval for λ (95%)
5. The estimator θ̂ and its confidence interval via delta method (95%)
6. Estimate the empirical coverage probability of both intervals using Monte-Carlo
   simulation (at least 5000 repetitions).
